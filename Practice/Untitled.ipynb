# %%
import pandas as pd
test_data = pd.read_csv('Keyword_spam_question.csv')
#print(data)
index = test_data["index"]
name = test_data["name"]
product = []
#print(index)
#print(len(name))
#print(name[0])
for i in range(len(name)):
    NAME = name[i]
    x = NAME.split()
    product.append(x)
#print(name)
#print(product[0], product[1])

keyword_data = pd.read_csv('Extra Material 2 - keyword list_with substring.csv')
print(keyword_data)
group = keyword_data["Group"]
keywords = keyword_data["Keywords"]
keyword = []
for i in range(len(keywords)):
    KEYWORDS = keywords[i].split(", ")
    keyword.append(KEYWORDS)
print(keyword)
# Out:
#      Group                                           Keywords
# 0        0                                       coat, jacket
# 1        1                                             blazer
# 2        2                       hoodies, sweater, sweatshirt
# 3        3                                               vest
# 4        4                                           cardigan
# ..     ...                                                ...
# 276    276  dry iron, garment steamers, steam iron, travel...
# 277    277                     washing machine, clothes dryer
# 278    278  crt tv, lcd tv, led tv, oled tv, plasma tv, ql...
# 279    279              tv remote control, tv antenna, tv box
# 280    280                                         wall mount
#
# [281 rows x 2 columns]
# ...
